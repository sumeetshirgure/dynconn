# %%
import numpy as np

from bqskit import Circuit, compile
from bqskit.ir.gates import CPGate, CSGate, CTGate
from bqskit.ext import bqskit_to_qiskit

import qiskit
from qiskit import QuantumCircuit, QuantumRegister

# %%
qft = qiskit.circuit.library.QFT(3, do_swaps=False, insert_barriers=True)
qft = qft.decompose()
qft.draw(output='mpl')

# %%
circ = Circuit(5)
circ.append_gate(CTGate(), (0, 4))

circ = compile(circ, optimization_level=4)

qc = bqskit_to_qiskit(circ)

# %%
qc.draw(output='mpl')
